# %% [markdown]
# # 1) Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from helpers import load_csv_data
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## 2)Loading cleaned data

# %% [markdown]
# Defining pathway to the dataset.

# %%
## INPUT ##
## input the path to the dataset
path=""

# %% [markdown]
# Loading cleaned data for feature ...
# Data cleaning performed:
# - NANs replaced with median
# - outliers - above ... and below ... percentile were removed

# %%
x_train,x_test,y_train = .....

# %% [markdown]
# ## 3) Data split

# %% [markdown]
# Splitting data into a training and testing sets.

# %%
## INPUT ##
## input % of dataset you want to use for testing 
testing_percentage=0.1

# %%
x_training, x_testing =split_data(x_train,y_train,testing_percentage, seed=1)

# %% [markdown]
# ## 4) Implementation

# %% [markdown]
# ## 5) Visualisation
